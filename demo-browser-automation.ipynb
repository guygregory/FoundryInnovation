# %% [markdown]
# # Browser automation tool in Azure AI Foundry Agent Service

# %% [markdown]
# DESCRIPTION:
#     This sample demonstrates how to use agent operations with the Browser Automation tool from
#     the Azure Agents service using a synchronous client.
#
# USAGE:
#     python sample_agents_browser_automation.py
#
#     Before running the sample:
#
#     pip install azure-ai-agents --pre
#     pip install azure-ai-projects azure-identity
#
#     Set these environment variables with your own values:
#     1) PROJECT_ENDPOINT - The Azure AI Project endpoint, as found in the Overview
#        page of your Azure AI Foundry portal.
#     2) AZURE_PLAYWRIGHT_CONNECTION_NAME - The name of a connection to the Azure Playwright Workspace as it is
#        listed in Azure AI Foundry connected resources.

# %%
import os
from azure.ai.projects import AIProjectClient
from azure.ai.agents.models import (
    MessageRole,
    RunStepToolCallDetails,
    BrowserAutomationTool,
    RunStepBrowserAutomationToolCall,
)
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv
load_dotenv()

project_client = AIProjectClient(endpoint=os.environ["PROJECT_ENDPOINT"], credential=DefaultAzureCredential())

# [START create_agent_with_browser_automation]
connection_id = project_client.connections.get(os.environ["AZURE_PLAYWRIGHT_CONNECTION_NAME"]).id

# Initialize Browser Automation tool and add the connection id
browser_automation = BrowserAutomationTool(connection_id=connection_id)

with project_client:

    agents_client = project_client.agents

    # Create a new Agent that has the Browser Automation tool attached.
    # Note: To add Browser Automation tool to an existing Agent with an `agent_id`, do the following:
    # agent = agents_client.update_agent(agent_id, tools=browser_automation.definitions)
    agent = agents_client.create_agent(
        model="gpt-4.1",
        name="Browser Automation Agent",
        instructions="""
            You are an Agent helping with browser automation tasks. 
            You can answer questions, provide information, and assist with various tasks 
            related to web browsing using the Browser Automation tool available to you.
            """,
        tools=browser_automation.definitions,
    )

    # [END create_agent_with_browser_automation]

    print(f"Created agent, ID: {agent.id}")

    # Create thread for communication
    thread = agents_client.threads.create()
    print(f"Created thread, ID: {thread.id}")

    # Create message to thread
    message = agents_client.messages.create(
        thread_id=thread.id,
        role=MessageRole.USER,
        content="""
            Your goal is to report the percent of Microsoft year-to-date stock price change.
            To do that, go to the website finance.yahoo.com.
            At the top of the page, you will find a search bar.
            Enter the value 'MSFT', to get information about the Microsoft stock price.
            At the top of the resulting page you will see a default chart of Microsoft stock price.
            Click on 'YTD' at the top of that chart, and report the percent value that shows up just below it.
            """,
    )
    print(f"Created message, ID: {message.id}")

    # Create and process agent run in thread with tools
    print(f"Waiting for Agent run to complete. Please wait...")
    run = agents_client.runs.create_and_process(thread_id=thread.id, agent_id=agent.id)
    print(f"Run finished with status: {run.status}")

    if run.status == "failed":
        print(f"Run failed: {run.last_error}")

    # Fetch run steps to get the details of the agent run
    run_steps = agents_client.run_steps.list(thread_id=thread.id, run_id=run.id)
    for step in run_steps:
        print(f"Step {step.id} status: {step.status}")

        if isinstance(step.step_details, RunStepToolCallDetails):
            print("  Tool calls:")
            tool_calls = step.step_details.tool_calls

            for call in tool_calls:
                print(f"    Tool call ID: {call.id}")
                print(f"    Tool call type: {call.type}")

                if isinstance(call, RunStepBrowserAutomationToolCall):
                    print(f"    Browser automation input: {call.browser_automation.input}")
                    print(f"    Browser automation output: {call.browser_automation.output}")

                    print("    Steps:")
                    for tool_step in call.browser_automation.steps:
                        print(f"      Last step result: {tool_step.last_step_result}")
                        print(f"      Current state: {tool_step.current_state}")
                        print(f"      Next step: {tool_step.next_step}")
                        print()  # add an extra newline between tool steps

                print()  # add an extra newline between tool calls

        print()  # add an extra newline between run steps

    # Optional: Delete the agent once the run is finished.
    # Comment out this line if you plan to reuse the agent later.
    agents_client.delete_agent(agent.id)
    print("Deleted agent")

    # Print the Agent's response message with optional citation
    response_message = agents_client.messages.get_last_message_by_role(thread_id=thread.id, role=MessageRole.AGENT)
    if response_message:
        for text_message in response_message.text_messages:
            print(f"Agent response: {text_message.text.value}")
        for annotation in response_message.url_citation_annotations:
            print(f"URL Citation: [{annotation.url_citation.title}]({annotation.url_citation.url})")
# Out:
# Created agent, ID: asst_2sKCO31dtFQAl6GRWEGnSF7n
# Created thread, ID: thread_QWDQmTrdEpnAbSIucRefDc4u
# Created message, ID: msg_yEkKaomuSMzFfP0Ajm8GcbI1
# Waiting for Agent run to complete. Please wait...
# Run finished with status: RunStatus.COMPLETED
# Step step_zz7pubwrMdozISu3gs0MPagu status: RunStepStatus.COMPLETED
#
# Step step_c6En8Kvjp0oxGWTCS5SCTBwC status: RunStepStatus.COMPLETED
#   Tool calls:
#     Tool call ID: call_OH07NP15vXMBxALQnVpDm2rd
#     Tool call type: browser_automation
#     Browser automation input: Go to https://finance.yahoo.com, search for 'MSFT', select Microsoft stock, click on 'YTD' on the price chart, and report the percent year-to-date change shown below it.
#     Browser automation output: The percent year-to-date (YTD) change for Microsoft Corporation (MSFT) on Yahoo Finance, as shown below the price chart in the 'Performance Overview: MSFT' section, is 22.72% as of 2025-09-22. This value reflects the official YTD return according to Yahoo Finance's methodology.
#
# Summary:
# - Stock: Microsoft Corporation (MSFT)
# - YTD Percent Change: 22.72%
# - As of Date: 2025-09-22
# - Location on Page: Performance Overview: MSFT section, under YTD Return
#
# If you need a screenshot or further details, please let me know!
#     Steps:
#       Last step result: Initial state; no previous action taken yet.
#       Current state: Task just started. No progress yet; need to open Yahoo Finance.
#       Next step: Navigate to https://finance.yahoo.com to begin the process.
#
#       Last step result: Successfully navigated to Yahoo Finance, but encountered a cookie consent popup. Need to resolve this before proceeding.
#       Current state: Landed on Yahoo Finance, but progress is blocked by a cookie consent popup. No search or stock selection done yet.
#       Next step: Click the 'Alles accepteren' (Accept all) button to dismiss the cookie popup and gain full access to the site.
#
#       Last step result: Successfully dismissed the cookie popup. The site is now ready for interaction.
#       Current state: Cookie popup dismissed, Yahoo Finance homepage fully loaded. Ready to search for MSFT using the quote lookup field.
#       Next step: Input 'MSFT' into the Quote Lookup field (index 100) and submit the search to access the Microsoft stock page.
#
#       Last step result: Successfully triggered the dropdown with MSFT search results. Verdict: Success.
#       Current state: Inputting 'MSFT' into the search field brought up the correct dropdown. Ready to select Microsoft Corporation (index 104). No progress yet on chart interaction or YTD change extraction.
#       Next step: Click on the 'Microsoft Corporation' result (index 104) to go to the MSFT stock page.
#
#       Last step result: Successfully navigated to the MSFT stock page. Ready to interact with the chart. Verdict: Success.
#       Current state: Arrived at the Microsoft (MSFT) stock page on Yahoo Finance. Ready to select 'YTD' on the price chart. No chart interaction or YTD data extraction done yet.
#       Next step: Click the 'YTD' button (index 44) on the price chart and extract the percent year-to-date change shown below it.
#
#       Last step result: Successfully extracted the percent year-to-date (YTD) change for MSFT from Yahoo Finance. Verdict: Success.
#       Current state: All steps completed: Yahoo Finance loaded, MSFT searched, stock selected, 'YTD' clicked, and YTD percent change (22.72%) extracted and verified. Ready to report result.
#       Next step: Report the extracted YTD percent change (22.72%) for MSFT to the user and mark the task as complete.
#
#
#
# Deleted agent
# Agent response: The year-to-date (YTD) percent change for Microsoft (MSFT) stock, as reported on Yahoo Finance, is 22.72% as of September 22, 2025. This value is shown just below the YTD chart on the stock's page. If you need a screenshot or additional details, please let me know!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
